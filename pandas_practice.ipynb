# %%
import pandas as pd 

data = {
    'Name': ['Bonolo', 'Lebo', 'Thato'],
    'Age' : [21,22,23]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0  Bonolo   21
# 1    Lebo   22
# 2   Thato   23
